# %% [markdown]
# Emily Wang | GF Baking | MatSci 2016
#
# ## Bend Tests!
#
# We have bend test data for...
#
# - XG
# - 1 Tsp Pectin
# - 3 Tsp Pectin
# - 8% Gluten (April 18)
# - 13% Gluten (April 18)
#
# The instron was being strange on XG bend test day. We noticed how its bend data was off from the others by orders of magnitude, so we're a bit skeptical of that particular plot.
#
# We don't have data for the March 28 trials of 8% Gluten and 13% Gluten.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from IPython.display import display
import numpy as np
import pprint as pp
# Out:
# /home/greenteawarrior/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %% [markdown]
# ### XG Bend Tests (Specimen 1, 2, 3)
#
# Data taken on March 24, 2016

# %%
# import
XG_bend1 = pd.read_csv('data/XG/XG_Bend_Data/XG_Bend_Specimen_RawData_1.csv', header=[0, 1])
XG_bend2 = pd.read_csv('data/XG/XG_Bend_Data/XG_Bend_Specimen_RawData_2.csv', header=[0, 1])
XG_bend3 = pd.read_csv('data/XG/XG_Bend_Data/XG_Bend_Specimen_RawData_3.csv', header=[0, 1])

# %%
# plotting
pw = plt.figure(figsize=(10,7))
plt.scatter(XG_bend1['Extension'].multiply(-1), XG_bend1['Load'].multiply(-1), color='red')
plt.scatter(XG_bend2['Extension'].multiply(-1), XG_bend2['Load'].multiply(-1), color='orange')
plt.scatter(XG_bend3['Extension'].multiply(-1), XG_bend3['Load'].multiply(-1), color='yellow')

# formatting
plt.title('Extension vs. Load for Bend Test XG Bread Specimen 1, 2, 3', fontsize=18)

plt.rc('xtick', labelsize=15) 
plt.rc('ytick', labelsize=15) 

axes = plt.gca()
axes.set_xlim([-1, 10])
axes.set_ylim([-.01, .03])

plt.xlabel('Extension (mm)', fontsize=18)
plt.ylabel('Load (N)', fontsize=18)

plt.legend(['Specimen 1', 'Specimen 2', 'Specimen 3'], loc=2, fontsize=16, bbox_to_anchor=(1.01, 1))
plt.show()

# uncomment if figure saving is desired
pw.savefig('figures/bend/XG_bend.pdf', format='pdf', bbox_inches='tight')
pw.savefig('figures/bend/XG_bend.png', format='png', bbox_inches='tight')

# %%
def plot_bend(dataframes, expname='', save=False, filename='bend_plot', bigger_ylim=False):
    
    # plotting
    pw = plt.figure(figsize=(10,7))
     
    colors = ['red', 'orange', 'yellow', 'green', 'blue', 'purple', 'gray', 'black', 'magenta', 'cyan']
    for i in range(len(dataframes)):
        # offsets
        if expname == '8% Gluten (April 18)' and i == 0:
            plt.plot(dataframes[i]['Extension'].subtract(1.21266).multiply(-1), dataframes[i]['Load'], color=colors[i], alpha=1.0)
        elif expname == '8% Gluten (April 18)' and i == 4:
            plt.plot(dataframes[i]['Extension'].subtract(4.28932).multiply(-1), dataframes[i]['Load'], color=colors[i], alpha=1.0)
        else:
            plt.plot(dataframes[i]['Extension'].multiply(-1), dataframes[i]['Load'], color=colors[i], alpha=1.0)
        
    # formatting
    plt.title('%s Flexural Stress-Strain Response (4 Point Bend)' % (expname), fontsize=18)
    plt.xlabel('Extension (mm)', fontsize=18)
    plt.ylabel('Load (N)', fontsize=18)
    
    plt.rc('xtick', labelsize=15) 
    plt.rc('ytick', labelsize=15) 
    
    axes = plt.gca()
    axes.set_xlim([-1, 9])
    if bigger_ylim:
        axes.set_ylim([-.0005, .001])
    else:
        axes.set_ylim([-.0002, .0006])
    
    plt.legend(['Specimen 1', 
                'Specimen 2', 
                'Specimen 3', 
                'Specimen 4', 
                'Specimen 5', 
                'Specimen 6', 
                'Specimen 7', 
                'Specimen 8'], 
                bbox_to_anchor=(1.01, 1), 
                loc=2, 
                fontsize=16)    
    plt.show()

    # saving the file
    if save:
        pw.savefig("figures/bend/%s.png" % filename, format='png', bbox_inches='tight')
        pw.savefig("figures/bend/%s.pdf" % filename, format='pdf', bbox_inches='tight')
    
    return

# %% [markdown]
# ### 1 Tsp Pectin

# %%
# import
pectin1tsp_bend1 = pd.read_csv('data/1TspPectin/1TspPectin_4PointBend.is_flex_RawData/Specimen_RawData_1.csv', header=[0, 1])
pectin1tsp_bend2 = pd.read_csv('data/1TspPectin/1TspPectin_4PointBend.is_flex_RawData/Specimen_RawData_2.csv', header=[0, 1])
pectin1tsp_bend3 = pd.read_csv('data/1TspPectin/1TspPectin_4PointBend.is_flex_RawData/Specimen_RawData_3.csv', header=[0, 1])
pectin1tsp_bend4 = pd.read_csv('data/1TspPectin/1TspPectin_4PointBend.is_flex_RawData/Specimen_RawData_4.csv', header=[0, 1])
pectin1tsp_bend5 = pd.read_csv('data/1TspPectin/1TspPectin_4PointBend.is_flex_RawData/Specimen_RawData_5.csv', header=[0, 1])
pectin1tsp_bend6 = pd.read_csv('data/1TspPectin/1TspPectin_4PointBend.is_flex_RawData/Specimen_RawData_6.csv', header=[0, 1])

# %%
pectin1tsp_bend1.head()
# Out:
#    Time Extension     Load
#   (sec)      (mm)      (N)
# 0  0.00   0.00000  0.00007
# 1  0.05  -0.00107 -0.00001
# 2  0.10  -0.00533 -0.00001
# 3  0.15  -0.01440 -0.00002
# 4  0.20  -0.02507  0.00001

# %%
plot_bend([pectin1tsp_bend1, pectin1tsp_bend2, pectin1tsp_bend3, pectin1tsp_bend4, pectin1tsp_bend5, pectin1tsp_bend6], 
          '1 Tsp Pectin', 
          True, 
          '1TspPectin_bend')

# %% [markdown]
# ### 3 Tsp Pectin

# %%
# import
pectin3tsp_bend1 = pd.read_csv('data/3TspPectin/3TspPectin_4PointBend.is_flex_RawData/Specimen_RawData_1.csv', header=[0, 1])
pectin3tsp_bend2 = pd.read_csv('data/3TspPectin/3TspPectin_4PointBend.is_flex_RawData/Specimen_RawData_2.csv', header=[0, 1])
pectin3tsp_bend3 = pd.read_csv('data/3TspPectin/3TspPectin_4PointBend.is_flex_RawData/Specimen_RawData_3.csv', header=[0, 1])
pectin3tsp_bend4 = pd.read_csv('data/3TspPectin/3TspPectin_4PointBend.is_flex_RawData/Specimen_RawData_4.csv', header=[0, 1])
pectin3tsp_bend5 = pd.read_csv('data/3TspPectin/3TspPectin_4PointBend.is_flex_RawData/Specimen_RawData_5.csv', header=[0, 1])

# %%
plot_bend([pectin3tsp_bend1, pectin3tsp_bend2, pectin3tsp_bend3, pectin3tsp_bend4, pectin3tsp_bend5], 
          '3 Tsp Pectin', 
          True, 
          '3TspPectin_bend', 
          bigger_ylim = True)

# %% [markdown]
# ### 8% Gluten (April 18)

# %%
# import
g2_8_bend1 = pd.read_csv('data/2_8PercentGluten/2_8gluten_4Point_1.is_flex_RawData/Specimen_RawData_1.csv', header=[0, 1])
g2_8_bend2 = pd.read_csv('data/2_8PercentGluten/2_8gluten_4Point_1.is_flex_RawData/Specimen_RawData_2.csv', header=[0, 1])
g2_8_bend3 = pd.read_csv('data/2_8PercentGluten/2_8gluten_4Point_1.is_flex_RawData/Specimen_RawData_3.csv', header=[0, 1])
g2_8_bend4 = pd.read_csv('data/2_8PercentGluten/2_8gluten_4Point_1.is_flex_RawData/Specimen_RawData_4.csv', header=[0, 1])
g2_8_bend5 = pd.read_csv('data/2_8PercentGluten/2_8gluten_4Point_1.is_flex_RawData/Specimen_RawData_5.csv', header=[0, 1])
g2_8_bend6 = pd.read_csv('data/2_8PercentGluten/2_8gluten_4Point_1.is_flex_RawData/Specimen_RawData_6.csv', header=[0, 1])

# %%
g2_8_bend1.head()
# Out:
#    Time Extension     Load
#   (sec)      (mm)      (N)
# 0  0.00   1.21266 -0.00008
# 1  0.05   1.21146 -0.00014
# 2  0.10   1.20666 -0.00013
# 3  0.15   1.19720 -0.00009
# 4  0.20   1.18680 -0.00013

# %%
g2_8_bend5.head()
# Out:
#    Time Extension     Load
#   (sec)      (mm)      (N)
# 0  0.00   4.28932 -0.00006
# 1  0.05   4.28812 -0.00013
# 2  0.10   4.28332 -0.00011
# 3  0.15   4.27399 -0.00012
# 4  0.20   4.26359 -0.00009

# %%
plot_bend([g2_8_bend1, g2_8_bend2, g2_8_bend3, g2_8_bend4, g2_8_bend5, g2_8_bend6], 
          '8% Gluten (April 18)', 
          True, 
          '2_8PercentGluten_bend')

# %% [markdown]
# ### 13% Gluten (April 18)

# %%
# import
g2_13_bend1 = pd.read_csv('data/2_13PercentGluten/2_13gluten_4Point.is_flex_RawData/Specimen_RawData_1.csv', header=[0, 1])
g2_13_bend2 = pd.read_csv('data/2_13PercentGluten/2_13gluten_4Point.is_flex_RawData/Specimen_RawData_2.csv', header=[0, 1])
g2_13_bend3 = pd.read_csv('data/2_13PercentGluten/2_13gluten_4Point.is_flex_RawData/Specimen_RawData_3.csv', header=[0, 1])
g2_13_bend4 = pd.read_csv('data/2_13PercentGluten/2_13gluten_4Point.is_flex_RawData/Specimen_RawData_4.csv', header=[0, 1])
g2_13_bend5 = pd.read_csv('data/2_13PercentGluten/2_13gluten_4Point.is_flex_RawData/Specimen_RawData_5.csv', header=[0, 1])
g2_13_bend6 = pd.read_csv('data/2_13PercentGluten/2_13gluten_4Point.is_flex_RawData/Specimen_RawData_6.csv', header=[0, 1])

# %%
plot_bend([g2_13_bend1, g2_13_bend2, g2_13_bend3, g2_13_bend4, g2_13_bend5, g2_13_bend6], 
          '13% Gluten (April 18)', 
          True, 
          '2_13PercentGluten_bend')
